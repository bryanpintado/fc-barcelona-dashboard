# %%
# !which python3
# Out:
# /Users/bryan/Projects/data_science/.venv/bin/python3

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from datetime import datetime

# %%
text = requests.get('https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-1').text
text
# Out:
# '<!DOCTYPE html><html lang="en"><head><link href="https://assets.laliga.com/assets/sprites/shield-sprite.css?20240818124418543565" rel="stylesheet"/><link href="https://assets.laliga.com/assets/public/fonts/fonts.css?20250121163400" rel="stylesheet"/><link rel="preconnect" href="https://apim.laliga.com/public-service" crossorigin="anonymous"/><meta name="apple-itunes-app" content="app-id=968915185"/><link rel="icon" href="https://assets.laliga.com/assets/public/logos/favicon.ico"/><script type="text/javascript">!function(c,a){var b=a.createElement("script");b.type="text/javascript",b.crossorigin="anonymous",b.a,sync=!0,b.src="https://content.zeotap.com/sdk/idp.min.js",b.onload=function(){},(a=a.getElementsByTagName("script")[0]).parentNode.insertBefore(b,a),function(c,b,d){for(var a=0;a<b.length;a++)!function(a){c[a]=function(){c["_q"].push([a].concat(Array.prototype.slice.call(arguments,0)))}}(b[a])}(a=c.zeotap||{_q:[],_qcmp:[]},["callMethod"],"_q"),c.zeotap=a,c.zeotap.callMethod("init",{partnerId:"bc1e256c-390b-4295-a4ce-789998f5b409"},{useConsent:!0},{checkForCMP:!0},{partner_dom:"https://www.laliga.com"})}(window,document)</script><script>\n            window.dataLayer = window.dataLayer || [];\n            window.dataLayer.push({\n            originalLocation: document.location.protocol + \'//\' +\n            document.location.hostname +\n            document.location.pathname +\n            document.location.search\n            });\n          </script><script id="gtm-js" async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5TTHMSV"></script><script>\n            window.dataLayer = window.dataLayer || [];\n            function gtag(){dataLayer.push(arguments);}\n            gtag(\'js\', new Date());\n            gtag(\'config\', \'GTM-5TTHMSV\');\n            (function intercept() {\n    const qs = document.querySelector(\'#gtm-js\');\n\n    if (qs !== null) {\n      qs.addEventListener(\'load\', function () {\n        // console.log(\'GTM loaded\')\n        return \'GTM loaded\';\n      });\n    }\n  })()\n          </script><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:site" content="@laliga"/><meta name="twitter:creator" content="@laliga"/><meta property="og:type" content="website"/><meta property="og:site_name" content="Página web oficial de LALIGA | LALIGA"/><script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type":"SiteNavigationElement",\n    "@id":"LALIGA",\n    "name": "LALIGA EA SPORTS",\n    "url": "https://www.laliga.com/en-GB/laliga-easports"\n  }</script><script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type":"SiteNavigationElement",\n    "@id":"LALIGA",\n    "name": "LALIGA HYPERMOTION",\n    "url": "https://www.laliga.com/en-GB/laliga-hypermotion"\n  }</script><script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type":"SiteNavigationElement",\n    "@id":"LALIGA",\n    "name": "Liga F",\n    "url": "https://www.laliga.com/en-GB/futbol-femenino"\n  }</script><script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type":"SiteNavigationElement",\n    "@id":"LALIGA",\n    "name": "LALIGA GENUINE",\n    "url": "https://www.laliga.com/en-GB/laliga-genuine"\n  }</script><script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type":"SiteNavigationElement",\n    "@id":"LALIGA",\n    "name": "LALIGA Videos",\n    "url": "https://www.laliga.com/en-GB/videos"\n  }</script><script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type":"SiteNavigationElement",\n    "@id":"LALIGA",\n    "name": "LALIGA News",\n    "url": "https://www.laliga.com/en-GB/news"\n  }</script><script type="application/ld+json">\n  {\n    "@context": "https://schema.org",\n    "@type":"SiteNavigationElement",\n    "@id":"LALIGA",\n    "nam ...

# %%
soup = BeautifulSoup(text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link href="https://assets.laliga.com/assets/sprites/shield-sprite.css?20240818124418543565" rel="stylesheet"/><link href="https://assets.laliga.com/assets/public/fonts/fonts.css?20250121163400" rel="stylesheet"/><link crossorigin="anonymous" href="https://apim.laliga.com/public-service" rel="preconnect"/><meta content="app-id=968915185" name="apple-itunes-app"/><link href="https://assets.laliga.com/assets/public/logos/favicon.ico" rel="icon"/><script type="text/javascript">!function(c,a){var b=a.createElement("script");b.type="text/javascript",b.crossorigin="anonymous",b.a,sync=!0,b.src="https://content.zeotap.com/sdk/idp.min.js",b.onload=function(){},(a=a.getElementsByTagName("script")[0]).parentNode.insertBefore(b,a),function(c,b,d){for(var a=0;a<b.length;a++)!function(a){c[a]=function(){c["_q"].push([a].concat(Array.prototype.slice.call(arguments,0)))}}(b[a])}(a=c.zeotap||{_q:[],_qcmp:[]},["callMethod"],"_q"),c.zeotap=a,c.zeotap.callMethod("init",{partnerId:"bc1e256c-390b-4295-a4ce-789998f5b409"},{useConsent:!0},{checkForCMP:!0},{partner_dom:"https://www.laliga.com"})}(window,document)</script><script>
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#             originalLocation: document.location.protocol + '//' +
#             document.location.hostname +
#             document.location.pathname +
#             document.location.search
#             });
#           </script><script async="" id="gtm-js" src="https://www.googletagmanager.com/gtm.js?id=GTM-5TTHMSV"></script><script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag(){dataLayer.push(arguments);}
#             gtag('js', new Date());
#             gtag('config', 'GTM-5TTHMSV');
#             (function intercept() {
#     const qs = document.querySelector('#gtm-js');
#
#     if (qs !== null) {
#       qs.addEventListener('load', function () {
#         // console.log('GTM loaded')
#         return 'GTM loaded';
#       });
#     }
#   })()
#           </script><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><meta content="summary_large_image" name="twitter:card"/><meta content="@laliga" name="twitter:site"/><meta content="@laliga" name="twitter:creator"/><meta content="website" property="og:type"/><meta content="Página web oficial de LALIGA | LALIGA" property="og:site_name"/><script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type":"SiteNavigationElement",
#     "@id":"LALIGA",
#     "name": "LALIGA EA SPORTS",
#     "url": "https://www.laliga.com/en-GB/laliga-easports"
#   }</script><script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type":"SiteNavigationElement",
#     "@id":"LALIGA",
#     "name": "LALIGA HYPERMOTION",
#     "url": "https://www.laliga.com/en-GB/laliga-hypermotion"
#   }</script><script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type":"SiteNavigationElement",
#     "@id":"LALIGA",
#     "name": "Liga F",
#     "url": "https://www.laliga.com/en-GB/futbol-femenino"
#   }</script><script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type":"SiteNavigationElement",
#     "@id":"LALIGA",
#     "name": "LALIGA GENUINE",
#     "url": "https://www.laliga.com/en-GB/laliga-genuine"
#   }</script><script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type":"SiteNavigationElement",
#     "@id":"LALIGA",
#     "name": "LALIGA Videos",
#     "url": "https://www.laliga.com/en-GB/videos"
#   }</script><script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type":"SiteNavigationElement",
#     "@id":"LALIGA",
#     "name": "LALIGA News",
#     "url": "https://www.laliga.com/en-GB/news"
#   }</script><script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type":"SiteNavigationElement",
#     "@id":"LALIGA",
#     "name": "LALIGA Stats",
#     "url": "https://www.laliga.com/en-GB/stats/laliga-easports/scorers"
#   }</script><script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type":"SiteNavigationElement",
#     "@id":"LALIGA",
#     "name": "LALIGA Photo Galleries",
#     "url": "https://www.laliga.com/en-GB/multimedia"
#   }</script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org",
#     "@type": "WebPage",
#     "name": "LALIGA official website | LALIGA",
#     "url": "https://www.laliga.com/en-GB",
#     "description": "All the information of LALIGA EA SPORTS, LALIGA HYPERMOTION, and Liga F: schedules, results, standings, news, statistics, and much more"
#   }</script><link href="https://www.laliga.com/laliga-easports/resultados" hreflang="es" rel="alternate" type="text/html"/><link href="https://www.laliga.com/en-GB/laliga-easports/results" hreflang="en" rel="alternate" type="text/html"/><link href="https://www.laliga.com/en-GB/laliga-easports/results" hreflang="x-default" rel="alternate"/><title>Results of Matchday 1 of LALIGA EA SPORTS 2024/25 | LALIGA</title><meta content="index,follow" name="robots"/><meta content="index,follow" name="googlebot"/><meta content="Find out the results of Matchday 1 of LALIGA and the previous ones of LALIGA EA SPORTS. Keep yourself informed about the First Division of soccer!" name="description"/><meta content="Results of Matchday 1 of LALIGA EA SPORTS 2024/25" property="og:title"/><meta content="Find out the results of Matchday 1 of LALIGA and the previous ones of LALIGA EA SPORTS. Keep yourself informed about the First Division of soccer!" property="og:description"/><meta content="https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-1" property="og:url"/><meta content="en" property="og:locale"/><link href="https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-1" rel="canonical"/><script type="application/ld+json">
#   {
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#       {
#           "@type": "ListItem",
#           "item":
#             {
#               "@id": "subhome",
#               "name": "LALIGA EA SPORTS"
#             },
#           "position": "0"
#           }
#      ]
#   }</script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-15T17:00:00+00:00",
#     "endDate": "2024-08-15T18:45:00Z",
#     "name": "🏟️⚽️ Athletic Club - Getafe CF",
#     "description": "Partido de LALIGA EA SPORTS entre Athletic Club - Getafe CF",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-athletic-club-getafe-cf-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "Getafe CF",
#       "image": "https://assets.laliga.com/assets/2023/05/12/medium/dc59645c96bc2c9010341c16dd6d4bfa.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "Athletic Club",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/athletic.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Estadio San Mamés",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "Getafe CF"
#       },
#       {
#         "@type": "Organization",
#         "name": "Athletic Club"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-15T19:30:00+00:00",
#     "endDate": "2024-08-15T21:15:00Z",
#     "name": "🏟️⚽️ Real Betis - Girona FC",
#     "description": "Partido de LALIGA EA SPORTS entre Real Betis - Girona FC",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-real-betis-girona-fc-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "Girona FC",
#       "image": "https://assets.laliga.com/assets/2022/06/22/medium/8f43addbb29e4a72f5e90b6edfe4728f.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "Real Betis",
#       "image": "https://assets.laliga.com/assets/2022/09/15/medium/e4a09419d3bd115b8f3dab73d480e146.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Estadio Benito Villamarín",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "Girona FC"
#       },
#       {
#         "@type": "Organization",
#         "name": "Real Betis"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-16T17:00:00+00:00",
#     "endDate": "2024-08-16T18:45:00Z",
#     "name": "🏟️⚽️ RC Celta - Deportivo Alavés",
#     "description": "Partido de LALIGA EA SPORTS entre RC Celta - Deportivo Alavés",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-rc-celta-deportivo-alaves-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "Deportivo Alavés",
#       "image": "https://assets.laliga.com/assets/2020/09/01/medium/27002754a98bf535807fe49a24cc63ea.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "RC Celta",
#       "image": "https://d2bk74em32frqb.cloudfront.net/assets/2019/06/07/medium/celta.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Estadio ABANCA Balaídos",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "Deportivo Alavés"
#       },
#       {
#         "@type": "Organization",
#         "name": "RC Celta"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-16T19:30:00+00:00",
#     "endDate": "2024-08-16T21:15:00Z",
#     "name": "🏟️⚽️ UD Las Palmas - Sevilla FC",
#     "description": "Partido de LALIGA EA SPORTS entre UD Las Palmas - Sevilla FC",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-ud-las-palmas-sevilla-fc-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "Sevilla FC",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/sevilla.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "UD Las Palmas",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/las-palmas.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Estadio Gran Canaria",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "Sevilla FC"
#       },
#       {
#         "@type": "Organization",
#         "name": "UD Las Palmas"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-17T17:00:00+00:00",
#     "endDate": "2024-08-17T18:45:00Z",
#     "name": "🏟️⚽️ CA Osasuna - CD Leganés",
#     "description": "Partido de LALIGA EA SPORTS entre CA Osasuna - CD Leganés",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-ca-osasuna-cd-leganes-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "CD Leganés",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/leganes.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "CA Osasuna",
#       "image": "https://d2bk74em32frqb.cloudfront.net/assets/2019/06/07/medium/osasuna.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Estadio El Sadar",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "CD Leganés"
#       },
#       {
#         "@type": "Organization",
#         "name": "CA Osasuna"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-17T19:30:00+00:00",
#     "endDate": "2024-08-17T21:15:00Z",
#     "name": "🏟️⚽️ Valencia CF - FC Barcelona",
#     "description": "Partido de LALIGA EA SPORTS entre Valencia CF - FC Barcelona",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-valencia-cf-fc-barcelona-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "FC Barcelona",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/barcelona.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "Valencia CF",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/valencia.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Camp de Mestalla",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "FC Barcelona"
#       },
#       {
#         "@type": "Organization",
#         "name": "Valencia CF"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-18T17:00:00+00:00",
#     "endDate": "2024-08-18T18:45:00Z",
#     "name": "🏟️⚽️ Real Sociedad - Rayo Vallecano",
#     "description": "Partido de LALIGA EA SPORTS entre Real Sociedad - Rayo Vallecano",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-real-sociedad-rayo-vallecano-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "Rayo Vallecano",
#       "image": "https://assets.laliga.com/assets/2023/04/27/medium/57d9950a8745ead226c04d37235c0786.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "Real Sociedad",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/real-sociedad.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Reale Arena",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "Rayo Vallecano"
#       },
#       {
#         "@type": "Organization",
#         "name": "Real Sociedad"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-18T19:30:00+00:00",
#     "endDate": "2024-08-18T21:15:00Z",
#     "name": "🏟️⚽️ RCD Mallorca - Real Madrid",
#     "description": "Partido de LALIGA EA SPORTS entre RCD Mallorca - Real Madrid",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-rcd-mallorca-real-madrid-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "Real Madrid",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/real-madrid.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "RCD Mallorca",
#       "image": "https://assets.laliga.com/assets/2023/03/22/medium/013ae97735bc8e519dcf30f6826168ca.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Estadi Mallorca Son Moix",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "Real Madrid"
#       },
#       {
#         "@type": "Organization",
#         "name": "RCD Mallorca"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-19T17:00:00+00:00",
#     "endDate": "2024-08-19T18:45:00Z",
#     "name": "🏟️⚽️ Real Valladolid CF - RCD Espanyol de Barcelona",
#     "description": "Partido de LALIGA EA SPORTS entre Real Valladolid CF - RCD Espanyol de Barcelona",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-real-valladolid-cf-rcd-espanyol-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "RCD Espanyol de Barcelona",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/espanyol.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "Real Valladolid CF",
#       "image": "https://assets.laliga.com/assets/2024/06/17/medium/1467dcd5efb813a742d86f8eb39504a3.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Estadio Municipal José Zorrilla",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "RCD Espanyol de Barcelona"
#       },
#       {
#         "@type": "Organization",
#         "name": "Real Valladolid CF"
#       }
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org/",
#     "@type": "SportsEvent",
#     "startDate": "2024-08-19T19:30:00+00:00",
#     "endDate": "2024-08-19T21:15:00Z",
#     "name": "🏟️⚽️ Villarreal CF - Atlético de Madrid",
#     "description": "Partido de LALIGA EA SPORTS entre Villarreal CF - Atlético de Madrid",
#     "image": "",
#     "url": "https://www.laliga.com/partido/temporada-2024-2025-laliga-ea-sports-villarreal-cf-atletico-de-madrid-1",
#     "awayTeam": {
#       "@type": "Thing",
#       "name": "Atlético de Madrid",
#       "image": "https://d2bk74em32frqb.cloudfront.net/assets/2024/06/17/medium/cbc5c8cc8c3e8abd0e175c00ee53b723.png"
#     },
#     "homeTeam": {
#       "@type": "Thing",
#       "name": "Villarreal CF",
#       "image": "https://assets.laliga.com/assets/2019/06/07/medium/villarreal.png"
#     },
#     "location": {
#       "@type": "Place",
#       "name": "Estadio de la Cerámica",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "undefined"
#       }
#     },
#     "performer": [
#       {
#         "@type": "Organization",
#         "name": "Atlético de Madrid"
#       },
#       {
#         "@type": "Organization",
#         "name": "Villarreal CF"
#       }
#     ]
#   }
#   </script><meta content="39" name="next-head-count"/><link as="style" href="/_next/static/css/9233e105d2b501fa253e.css" rel="preload"/><link data-n-g="" href="/_next/static/css/9233e105d2b501fa253e.css" rel="stylesheet"/><noscript data-n-css=""></noscript><link as="script" href="/_next/static/chunks/35.df8a473e42597454a841.js" rel="preload"/><link as="script" href="/_next/static/chunks/webpack-a087cbef59e7765c2d3d.js" rel="preload"/><link as="script" href="/_next/static/chunks/framework.6c2884e1927893ca3e5e.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.5021ceb3fa6489e67cf2.js" rel="preload"/><link as="script" href="/_next/static/chunks/9be2f4c42016d6ba52ee8e7ea3a5fa3a5f25a2b5.e8df725471de34c097f7.js" rel="preload"/><link as="script" href="/_next/static/chunks/main-1629769118f897536f80.js" rel="preload"/><link as="script" href="/_next/static/chunks/2852872c.d24731fb8d038cfd943e.js" rel="preload"/><link as="script" href="/_next/static/chunks/75fc9c18.c5f381fba2b0f9a9f346.js" rel="preload"/><link as="script" href="/_next/static/chunks/ea88be26.c683b7320b0d7110e1ab.js" rel="preload"/><link as="script" href="/_next/static/chunks/14e77deee422232573d6acaff44e6056b72bf046.4ac52cf92a7c0ee50053.js" rel="preload"/><link as="script" href="/_next/static/chunks/15df18bb7891ecf8da0223c88db08e52952baf02.d8e5d14953f7fae1c206.js" rel="preload"/><link as="script" href="/_next/static/chunks/5355ce7f8195fb32cea827849e6d8766fadf88c0.2f526853672bd7913ac2.js" rel="preload"/><link as="script" href="/_next/static/chunks/e423a111fb479221d31d910b77e768e7ef4c883e.eddf1844e27a50ba3cdd.js" rel="preload"/><link as="script" href="/_next/static/chunks/577880cd100258a0d2562f8c661fd8eaeb7ba831.b6795be539507e093630.js" rel="preload"/><link as="script" href="/_next/static/chunks/5c6ef015c78baa7610dba900c4055c6e0f8bf4ec.c03e5aa89f11378cd2a4.js" rel="preload"/><link as="script" href="/_next/static/chunks/e5731c43aeb897530b0b847726bfdda9cd13f037.e43065d07000248e0b67.js" rel="preload"/><link as="script" href="/_next/static/chunks/a532a959755831b4fdde1c795c38fdadd9225ac7.0789f025c2a55bc8cb3e.js" rel="preload"/><link as="script" href="/_next/static/chunks/fe60be749e5ac922f2fb5eeb8832d98577adb44e.bdd1368c2a348438a5ce.js" rel="preload"/><link as="script" href="/_next/static/chunks/2534823d8d33aa50068727c99d86e7cf788ffe7b.dac03aa41dd79579c3c9.js" rel="preload"/><link as="script" href="/_next/static/chunks/dc9b96e92db1a473c390520cfdeac347a3645069.a16df7ad19940c91cbd5.js" rel="preload"/><link as="script" href="/_next/static/chunks/06101683719044a9a60d84aef8b6148174c3a8bc.740e91b5b449f6283947.js" rel="preload"/><link as="script" href="/_next/static/chunks/83776181d3039be4015b57710618722532b125e3.88dcbcb894596aa6906d.js" rel="preload"/><link as="script" href="/_next/static/chunks/8b17d70cfcba0d0c8e7c9959c9d18e5b440b47ca.29dd4da01ad39de72cf7.js" rel="preload"/><link as="script" href="/_next/static/chunks/9a8143680932472a94313e9c96f4a32455f2a75e.5101eba97e0fd11ac8ee.js" rel="preload"/><link as="script" href="/_next/static/chunks/12308cb911c47db62b6a863bf196bc9b1dfa30d5.495d3668d4fdf37e776d.js" rel="preload"/><link as="script" href="/_next/static/chunks/5f1ce689ee82449bbdcd72818fab4cc9a1c74c5e.f31bf7af2ed78baf2b79.js" rel="preload"/><link as="script" href="/_next/static/chunks/a5e165e8dd65a352b69203dee6ee5f185a908200.25fffa5078a793fdbe38.js" rel="preload"/><link as="script" href="/_next/static/chunks/pages/_app-dfbb701762d45e59e543.js" rel="preload"/><link as="script" href="/_next/static/chunks/ee72371e9301406c3c207d0fc3ab69440bf2f941.79762eb22c8b79f574f6.js" rel="preload"/><link as="script" href="/_next/static/chunks/2dc511f0442f77974d8dd20ad7bab467c1eaa269.b780deaffe75c97b60b7.js" rel="preload"/><link as="script" href="/_next/static/chunks/fca2cc7ee99119ff9e487b32ec19fc9e00045ee8.13ea8570f4fd81e9d687.js" rel="preload"/><link as="script" href="/_next/static/chunks/dcf9fe64432175e9adbf976cda9494244397d3cb.c70b800ac053f0718f7c.js" rel="preload"/><link as ...
# html{width:100%;min-height:100%;-webkit-scroll-behavior:smooth;-moz-scroll-behavior:smooth;-ms-scroll-behavior:smooth;scroll-behavior:smooth;}/*!sc*/
# a{-webkit-text-decoration:none;text-decoration:none;color:inherit;cursor:pointer;-webkit-transition:opacity 0.3s;transition:opacity 0.3s;}/*!sc*/
# a:hover{opacity:0.7;}/*!sc*/
# body{width:100%;height:100%;background:white;margin:0;box-sizing:border-box;}/*!sc*/
# .overflowHidden{overflow:hidden;}/*!sc*/
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font-size:100%;vertical-align:baseline;outline:0;}/*!sc*/
# button:focus,input:focus,select:focus,textarea:focus{outline:0;}/*!sc*/
# article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}/*!sc*/
# body{line-height:1;}/*!sc*/
# ol,ul{list-style:none;}/*!sc*/
# blockquote,q{quotes:none;}/*!sc*/
# blockquote:after,blockquote:before,q:after,q:before{content:'';content:none;}/*!sc*/
# table{border-collapse:collapse;border-spacing:0;}/*!sc*/
# a{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# textarea{resize:none;}/*!sc*/
# .clearfix:after{visibility:hidden;display:block;font-size:0;content:" ";clear:both;height:0;}/*!sc*/
# * html .clearfix{height:1%;}/*!sc*/
# .clearfix{display:block;}/*!sc*/
# *{-moz-box-sizing:border-box;-webkit-box-sizing:border-box;box-sizing:border-box;}/*!sc*/
# body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-rendering:optimizeLegibility;-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-text-size-adjust:100%;}/*!sc*/
# a.active,a.focus,a.visited,a.hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# input,label,select,button,textarea{margin:0;border:0;padding:0;display:inline-block;vertical-align:middle;white-space:normal;background:none;line-height:1;font-size:13px;font-family:'LaLiga Text';}/*!sc*/
# input:focus{outline:0;}/*!sc*/
# input,textarea{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;}/*!sc*/
# button,input[type=reset],input[type=button],input[type=submit],input[type=checkbox],input[type=radio],select{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;}/*!sc*/
# input[type=checkbox],input[type=radio]{width:13px;height:13px;}/*!sc*/
# input[type=search]{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;}/*!sc*/
# ::-webkit-search-decoration{display:none;}/*!sc*/
# button,input[type="reset"],input[type="button"],input[type="submit"]{overflow:visible;width:auto;}/*!sc*/
# ::-webkit-file-upload-button{padding:0;border:0;background:none;}/*!sc*/
# textarea{vertical-align:top;overflow:auto;}/*!sc*/
# select[multiple]{vertical-align:top;}/*!sc*/
# input[type="search"]::-webkit-search-decoration,input[type="search"]::-webkit-search-cancel-button,input[type="search"]::-webkit-search-results-button,input[type="search"]::-webkit-search-results-decoration{display:none;}/*!sc*/
# input,label,select,button,textarea{-webkit-border-radius:0;-moz-border-radius:0;border-radius:0;}/*!sc*/
# input[type=range]{-webkit-appearance:none;width:100%;}/*!sc*/
# input[type=range]::-webkit-slider-thumb{-webkit-appearance:none;}/*!sc*/
# input[type=range]:focus{outline:none;}/*!sc*/
# input[type=range]::-ms-track{width:100%;cursor:pointer;background:transparent;border-color:transparent;color:transparent;}/*!sc*/
# data-styled.g1[id="sc-global-srkNb1"]{content:"sc-global-srkNb1,"}/*!sc*/
# .fpSspd{display:block;position:fixed;top:0px;left:0px;width:100vw;height:100vh;background-color:#000000a1;z-index:99999;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .fpSspd.show{opacity:0;-webkit-animation:lbWRkT 0.3s ease-in;animation:lbWRkT 0.3s ease-in;-webkit-animation-delay:0.4s;animation-delay:0.4s;-webkit-animation-fill-mode:forwards;animation-fill-mode:forwards;}/*!sc*/
# .fpSspd.hide{display:none;}/*!sc*/
# data-styled.g2[id="styled__SpinnerContainer-sc-uwgd15-0"]{content:"fpSspd,"}/*!sc*/
# .fVlOEb{font-family:'font-laliga';text-align:center;font-size:0.4rem;color:black;margin:0 5px;}/*!sc*/
# .blWsGz{font-family:'font-laliga';text-align:center;font-size:1.2rem;color:#FFFFFF;margin:0 6px 0 0;}/*!sc*/
# .bmwORV{font-family:'font-laliga';text-align:center;font-size:1.25rem;color:black;margin:0 5px;}/*!sc*/
# .gEpDID{font-family:'font-laliga';text-align:center;font-size:1rem;color:#00001b;margin:0 5px;}/*!sc*/
# .eqKEoH{font-family:'font-laliga';text-align:center;font-size:1.5rem;color:black;margin:0 5px;}/*!sc*/
# .jEmzdD{font-family:'font-laliga';text-align:center;font-size:1.2rem;color:#00001b;margin:0 5px;}/*!sc*/
# .kIoxBI{font-family:'font-laliga';text-align:center;font-size:0.4rem;color:#00001b;margin:0 5px;}/*!sc*/
# .fcFMVW{font-family:'font-laliga';text-align:center;font-size:1.2rem;color:#00001b;margin:0px;}/*!sc*/
# .dOHtaX{font-family:'font-laliga';text-align:center;font-size:0.8rem;color:transparent;margin:0px;}/*!sc*/
# .emVBPI{font-family:'font-laliga';text-align:center;font-size:1rem;color:#FFFFFF;margin:0 5px;}/*!sc*/
# .jdwJJL{font-family:'font-laliga';text-align:center;font-size:0.8rem;color:#FFFFFF;margin:0 5px;}/*!sc*/
# .iLnnJw{font-family:'font-laliga';text-align:center;font-size:1rem;color:black;margin:0 5px;}/*!sc*/
# .hwIFst{font-family:'font-laliga';text-align:center;font-size:0.8rem;color:#FEF9CE;margin:0 5px;}/*!sc*/
# .eLDrjN{font-family:'font-laliga';text-align:center;font-size:0.4rem;color:#FF4B44;margin:0 5px;}/*!sc*/
# .bgiaXo{font-family:'font-laliga';text-align:center;font-size:0.8rem;color:#00001b;margin:0 5px;}/*!sc*/
# data-styled.g4[id="styled__IconRegularContainer-sc-1lapsw7-0"]{content:"fVlOEb,blWsGz,bmwORV,gEpDID,eqKEoH,jEmzdD,kIoxBI,fcFMVW,dOHtaX,emVBPI,jdwJJL,iLnnJw,hwIFst,eLDrjN,bgiaXo,"}/*!sc*/
# .kNfthj{width:100%;max-width:400px;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:white;}/*!sc*/
# .kNfthj > svg{width:100%;height:auto;padding:15% 0 0;}/*!sc*/
# .kNfthj > svg .llv-claim{display:none;}/*!sc*/
# .kNfthj > svg .llv-claim.llv-claim-en{display:initial;}/*!sc*/
# .kNfthj > svg .llv-claim,.kNfthj > svg .llv-name{display:none !important;}/*!sc*/
# .dZBYKf{width:100%;max-width:400px;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:transparent;}/*!sc*/
# .dZBYKf > svg{width:80px;height:auto;}/*!sc*/
# .dZBYKf > svg .llv-claim{display:none;}/*!sc*/
# .dZBYKf > svg .llv-claim.llv-claim-en{display:initial;}/*!sc*/
# .dZBYKf > svg .llv-character,.dZBYKf > svg .llh-character,.dZBYKf > svg .llg-character,.dZBYKf > svg .llg-character-detail{fill:#FFFFFF;}/*!sc*/
# .bvkmqV{width:100%;max-width:400px;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;background-color:transparent;}/*!sc*/
# .bvkmqV > svg{width:100%;height:auto;}/*!sc*/
# .bvkmqV > svg .llv-claim{display:none;}/*!sc*/
# .bvkmqV > svg .llv-claim.llv-claim-en{display:initial;}/*!sc*/
# .bvkmqV > svg .llv-character,.bvkmqV > svg .llv-petal,.bvkmqV > svg .llv-backball{fill:#ffffff;}/*!sc*/
# .bvkmqV > svg .llv-frontball{fill:transparent;}/*!sc*/
# .bDvGCU{width:100%;max-width:400px;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;background-color:white;}/*!sc*/
# .bDvGCU > svg{width:134px;height:auto;}/*!sc*/
# .bDvGCU > svg .llv-claim{display:none;}/*!sc*/
# .bDvGCU > svg .llv-claim.llv-claim-en{display:initial;}/*!sc*/
# data-styled.g6[id="styled__LogoLaLigaContainer-sc-1yhlepi-0"]{content:"kNfthj,dZBYKf,bvkmqV,bDvGCU,"}/*!sc*/
# .dXgpqT{font-family:'LaLiga Text';font-size:12px;line-height:120%;font-weight:400;}/*!sc*/
# .cYEkps{font-family:'LaLiga Text Bold';font-size:14px;line-height:120%;font-weight:400;}/*!sc*/
# .ejtpot{font-family:'LaLiga Text';font-size:14px;line-height:120%;font-weight:400;}/*!sc*/
# .XgneW{color:#00001b;font-family:'LaLiga Text Bold';font-size:16px;line-height:120%;font-weight:400;}/*!sc*/
# .cNKPWT{font-weight:400;}/*!sc*/
# .bDmhbs{color:#70707F;font-family:'LaLiga Text Bold';font-size:12px;line-height:120%;font-weight:400;}/*!sc*/
# .kNfrPo{font-family:'LaLiga Text Bold';font-size:18px;line-height:120%;font-weight:400;}/*!sc*/
# .lkqXsA{color:#00001b;font-family:'LaLiga Text Bold';font-size:14px;line-height:120%;font-weight:400;}/*!sc*/
# .bDJFpV{color:#00001b;font-family:'LaLiga Text';font-size:9px;line-height:120%;font-weight:400;}/*!sc*/
# .jnTiCY{font-family:'LaLiga Text Bold';font-size:9px;line-height:120%;font-weight:400;}/*!sc*/
# .eMQpft{font-family:'LaLiga Text';font-size:9px;line-height:120%;font-weight:400;}/*!sc*/
# .iPsmVf{color:#00001b;font-weight:400;}/*!sc*/
# .dUHLTw{font-family:'LaLiga Headline VF';font-variation-settings:'wght' 600,'wdth' 600;font-size:18px;line-height:100%;font-weight:400;}/*!sc*/
# @media (min-width:767px){.dUHLTw{font-size:18px;}}/*!sc*/
# .bXXfZR{font-family:'LaLiga Text';font-size:18px;line-height:120%;font-weight:400;}/*!sc*/
# .dvPPSE{color:#00001b;font-family:'LaLiga Text Bold';font-size:18px;line-height:120%;font-weight:400;}/*!sc*/
# .cXpDBb{color:#FFFFFF;font-family:'LaLiga Text Bold';font-size:18px;line-height:120%;font-weight:400;}/*!sc*/
# .iaVmTi{color:#FFFFFF;text-transform:uppercase;font-family:'LaLiga Text Bold';font-size:12px;line-height:120%;font-weight:400;}/*!sc*/
# .gquDwR{color:#FFFFFF;text-transform:uppercase;font-family:'LaLiga Headline VF';font-variation-settings:'wght' 800,'wdth' 440;font-size:26px;line-height:100%;font-weight:400;}/*!sc*/
# @media (min-width:767px){.gquDwR{font-size:32px;}}/*!sc*/
# .oSprF{color:white;font-family:'LaLiga Text Bold';font-size:12px;line-height:120%;font-weight:400;}/*!sc*/
# .JfTpq{color:white;text-transform:uppercase;font-family:'LaLiga Text Bold';font-size:16px;line-height:120%;font-weight:400;}/*!sc*/
# .bNUkWr{color:#FF4B44;font-family:'LaLiga Text Bold';font-size:12px;line-height:120%;font-weight:400;}/*!sc*/
# .budAXc{color:#00001b;font-family:'LaLiga Text Bold';font-size:10px;line-height:120%;font-weight:400;}/*!sc*/
# .jTXYPl{color:#00001b;text-transform:uppercase;font-family:'LaLiga Text Bold';font-size:12px;line-height:120%;font-weight:400;}/*!sc*/
# .gqRVUt{color:#FF4B44;font-family:'LaLiga Headline VF';font-variation-settings:'wght' 600,'wdth' 440;font-size:28px;line-height:100%;font-weight:400;}/*!sc*/
# .cwoAiu{color:#00001b;font-family:'LaLiga Text Bold';font-size:12px;line-height:120%;font-weight:400;}/*!sc*/
# .qpcHK{font-family:'LaLiga Text Bold';font-size:12px;line-height:120%;font-weight:400;}/*!sc*/
# .iNktpW{color:#70707F;font-family:'LaLiga Text Bold';font-size:9px;line-height:120%;font-weight:400;}/*!sc*/
# .fCNBIV{color:#70707F;text-align:center;font-family:'LaLiga Text Bold';font-size:14px;line-height:120%;font-weight:400;}/*!sc*/
# .kLQLaX{color:#FFFFFF;font-family:'LaLiga Text Bold';font-size:14px;line-height:120%;font-weight:400;}/*!sc*/
# data-styled.g9[id="styled__TextStyled-sc-1mby3k1-0"]{content:"dXgpqT,cYEkps,ejtpot,XgneW,cNKPWT,bDmhbs,kNfrPo,lkqXsA,bDJFpV,jnTiCY,eMQpft,iPsmVf,dUHLTw,bXXfZR,dvPPSE,cXpDBb,iaVmTi,gquDwR,oSprF,JfTpq,bNUkWr,budAXc,jTXYPl,gqRVUt,cwoAiu,qpcHK,iNktpW,fCNBIV,kLQLaX,"}/*!sc*/
# .esSirm{width:100%;max-width:1296px;margin:0 auto;position:relative;}/*!sc*/
# @media (max-width:1296px){.esSirm{padding:15px;}}/*!sc*/
# @media (max-width:900px){.esSirm{padding:10px;}}/*!sc*/
# data-styled.g36[id="styled__ContainerMax-sc-1ba2tmq-0"]{content:"esSirm,"}/*!sc*/
# .ecOiPu{opacity:1;position:relative;width:100%;background:transparent;border:1px solid transparent;padding-left:0.5rem;padding-right:0.5rem;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;border-radius:3px 3px 0 0;font-family:'LaLiga Text';font-size:14px;line-height:120%;color:#00001b;}/*!sc*/
# .ecOiPu > ul{z-index:100;}/*!sc*/
# .ecOiPu i,.ecOiPu p{color:inherit !important;}/*!sc*/
# .gpdfZV{opacity:1;position:relative;width:100%;background:transparent;border:1px solid transparent;padding-left:0.5rem;padding-right:0.5rem;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;border-radius:3px 3px 0 0;font-family:'LaLiga Text';font-size:14px;line-height:120%;color:#FFFFFF;}/*!sc*/
# .gpdfZV > ul{z-index:100;}/*!sc*/
# .gpdfZV i,.gpdfZV p{color:inherit !important;}/*!sc*/
# data-styled.g95[id="styled__DropdownContainer-sc-d9k1bl-0"]{content:"ecOiPu,gpdfZV,"}/*!sc*/
# .hKbUhh{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0.5rem 0rem 0.5rem 0.25rem;height:35px;position:relative;border-top-width:0px;border-bottom-width:0px;border-style:solid;border-top-color:transparent;border-bottom-color:#00001b;}/*!sc*/
# .hKbUhh > * + *{margin-left:0.5rem;}/*!sc*/
# .hKbUhh > span{text-overflow:ellipsis;overflow:hidden;white-space:nowrap;line-height:1.2;}/*!sc*/
# .hKbUhh:after{border-color:#00001b;}/*!sc*/
# .tYbQC{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0.5rem 0rem 0.5rem 0.25rem;height:35px;position:relative;border-top-width:1px;border-bottom-width:1px;border-style:solid;border-top-color:transparent;border-bottom-color:#FFFFFF;}/*!sc*/
# .tYbQC > * + *{margin-left:0.5rem;}/*!sc*/
# .tYbQC > span{text-overflow:ellipsis;overflow:hidden;white-space:nowrap;line-height:1.2;}/*!sc*/
# .tYbQC:after{border-color:({ theme, active }) => active ? theme.palette.contrasting.gray800 :theme.palette.contrasting.white;}/*!sc*/
# data-styled.g96[id="styled__SelectedItem-sc-d9k1bl-1"]{content:"hKbUhh,tYbQC,"}/*!sc*/
# .lofGQu{opacity:0;max-height:0;width:calc(100% + 2px);padding:0 0.5rem 0.5rem 0.5rem;overflow:auto;position:absolute;left:-1px;background-color:#FFFFFF;color:#00001b;border-style:solid;border-color:transparent;-webkit-overflow-scrolling:touch;top:100%;border-width:0px 1px 1px 1px;border-radius:0 0 3px 3px;}/*!sc*/
# .lofGQu::-webkit-scrollbar{width:10px;}/*!sc*/
# .lofGQu::-webkit-scrollbar-track{border-radius:8px;-webkit-border-radius:8px;}/*!sc*/
# .lofGQu::-webkit-scrollbar-thumb{-webkit-border-radius:10px;border-radius:10px;background:rgba(100,100,100,0.5);}/*!sc*/
# data-styled.g97[id="styled__ItemsList-sc-d9k1bl-2"]{content:"lofGQu,"}/*!sc*/
# .eXotyy{padding:0;}/*!sc*/
# .eXotyy a:hover{background-color:#FF4B44;opacity:1;}/*!sc*/
# .eXotyy:hover{background-color:#FF4B44;color:#FFFFFF;}/*!sc*/
# .fiLBip{padding:0;pointer-events:none;background-color:#FF4B44;color:#FFFFFF;}/*!sc*/
# .fiLBip a:hover{background-color:#FF4B44;opacity:1;}/*!sc*/
# .fiLBip:hover{background-color:#FF4B44;color:#FFFFFF;}/*!sc*/
# data-styled.g98[id="styled__Item-sc-d9k1bl-3"]{content:"eXotyy,fiLBip,"}/*!sc*/
# .gSZcFw{font-family:'LaLiga Text';font-size:12px;line-height:120%;color:#E32D38;}/*!sc*/
# .gSZcFw > span{display:block;}/*!sc*/
# data-styled.g99[id="styled__Error-sc-d9k1bl-4"]{content:"gSZcFw,"}/*!sc*/
# .forWqm{background-color:#FF4B44;height:56px;width:240px;padding-inline:16px;padding-block:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:4px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media (max-width:420px){.forWqm{width:100%;}}/*!sc*/
# data-styled.g113[id="styled__FanButtonStyle-sc-1nf4bls-0"]{content:"forWqm,"}/*!sc*/
# .ljMyNm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;gap:12px;}/*!sc*/
# @media (max-width:900px){.ljMyNm{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;max-width:504px;margin-left:auto;margin-right:auto;}.ljMyNm > div{-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;}}/*!sc*/
# @media (max-width:767px){.ljMyNm > p{margin-bottom:5px;width:100%;text-align:center;white-space:nowrap;}.ljMyNm > div{margin-left:0px;}}/*!sc*/
# data-styled.g114[id="styled__SocialLinksStyle-sc-9prkkl-0"]{content:"ljMyNm,"}/*!sc*/
# .jUoeAS{width:36px;height:36px;margin:0.25rem;-webkit-transition:background-color 0.3s,color 0.3s;transition:background-color 0.3s,color 0.3s;}/*!sc*/
# .jUoeAS span,.jUoeAS a{width:100%;height:100%;}/*!sc*/
# .jUoeAS a{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:inherit;}/*!sc*/
# .jUoeAS:hover{background-color:#FFFFFF;color:#00001b;}/*!sc*/
# data-styled.g115[id="styled__SocialLinkItem-sc-9prkkl-1"]{content:"jUoeAS,"}/*!sc*/
# .cpUYlp{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-top:30px;padding-bottom:30px;border-bottom:1px solid #eaeaea;}/*!sc*/
# @media (max-width:900px){.cpUYlp{padding-left:32px;padding-right:32px;}}/*!sc*/
# @media (max-width:900px){.cpUYlp{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding-top:24px;padding-left:0;padding-right:0;}}/*!sc*/
# data-styled.g116[id="styled__UpperSectionStyle-sc-1krsofz-0"]{content:"cpUYlp,"}/*!sc*/
# .fqlFEW{-webkit-box-flex:2;-webkit-flex-grow:2;-ms-flex-positive:2;flex-grow:2;}/*!sc*/
# @media (max-width:900px){.fqlFEW{padding-bottom:24px;margin-left:16px;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;}}/*!sc*/
# data-styled.g117[id="styled__LogoContainer-sc-1krsofz-1"]{content:"fqlFEW,"}/*!sc*/
# .eugTBB{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# @media (max-width:900px){.eugTBB{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# data-styled.g118[id="styled__LaLigaFanStyle-sc-1krsofz-2"]{content:"eugTBB,"}/*!sc*/
# .jMQwjQ{display:none;width:100%;padding:24px 0 16px 0;border-top:1px solid #EAEAEA;}/*!sc*/
# @media (max-width:900px){.jMQwjQ{display:block;}}/*!sc*/
# data-styled.g119[id="styled__SignUpTextStyle-sc-1krsofz-3"]{content:"jMQwjQ,"}/*!sc*/
# .hXAjUc{display:none;}/*!sc*/
# @media (max-width:900px){.hXAjUc{display:block;padding-block:24px;border-block:1px solid #EAEAEA;margin-top:24px;}}/*!sc*/
# data-styled.g131[id="styled__SocialLinksContainer-sc-pmhbk-11"]{content:"hXAjUc,"}/*!sc*/
# .kzSjGg{display:block;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}/*!sc*/
# @media (max-width:900px){.kzSjGg{display:none;}}/*!sc*/
# data-styled.g132[id="styled__SocialLinksContainerUpperSection-sc-pmhbk-12"]{content:"kzSjGg,"}/*!sc*/
# .fpvAuR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# @media (max-width:1024px){.fpvAuR{-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}}/*!sc*/
# @media (max-width:900px){.fpvAuR{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;gap:8px;}}/*!sc*/
# @media (max-width:420px){.fpvAuR{font-size:12px;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}}/*!sc*/
# data-styled.g135[id="styled__FooterLinkBarContainer-sc-1y0txcu-0"]{content:"fpvAuR,"}/*!sc*/
# .fncgjM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;gap:16px;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .fncgjM a{color:inherit;}/*!sc*/
# @media (max-width:1024px){.fncgjM{width:100%;}}/*!sc*/
# @media (max-width:900px){}/*!sc*/
# @media (max-width:420px){.fncgjM{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;min-height:120px;}}/*!sc*/
# data-styled.g136[id="styled__Links-sc-1y0txcu-1"]{content:"fncgjM,"}/*!sc*/
# .jBESxu{padding-left:4px;}/*!sc*/
# @media (max-width:900px){.jBESxu{padding-left:0px;margin-bottom:16px;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# @media (max-width:767px){.jBESxu{margin-bottom:0;}}/*!sc*/
# @media (max-width:420px){.jBESxu{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}}/*!sc*/
# data-styled.g137[id="styled__Left-sc-1y0txcu-2"]{content:"jBESxu,"}/*!sc*/
# @media (max-width:900px){.iMCurD{margin-bottom:16px;}}/*!sc*/
# @media (max-width:767px){.iMCurD{margin-bottom:0;}}/*!sc*/
# @media (max-width:420px){.iMCurD{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}}/*!sc*/
# data-styled.g138[id="styled__Center-sc-1y0txcu-3"]{content:"iMCurD,"}/*!sc*/
# @media (max-width:420px){.iGTkgC{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;margin-top:-24px;}}/*!sc*/
# data-styled.g139[id="styled__Right-sc-1y0txcu-4"]{content:"iGTkgC,"}/*!sc*/
# @media (max-width:420px){.hlVLaG{display:none;}}/*!sc*/
# data-styled.g140[id="styled__CopyRight-sc-1y0txcu-5"]{content:"hlVLaG,"}/*!sc*/
# .cawvtO{position:relative;margin:0 auto;max-width:1296px;}/*!sc*/
# @media (max-width:420px){.cawvtO{padding-inline:10px;}}/*!sc*/
# data-styled.g141[id="styled__FooterBottomContainer-sc-12934tu-0"]{content:"cawvtO,"}/*!sc*/
# .hTrXGU{padding-top:30px;padding-bottom:30px;color:#676b6e;}/*!sc*/
# @media (max-width:420px){.hTrXGU{padding-top:0;margin-top:-12px;}}/*!sc*/
# data-styled.g142[id="styled__BottomSectionStyle-sc-12934tu-1"]{content:"hTrXGU,"}/*!sc*/
# .fctWAl{grid-area:FOOTER;}/*!sc*/
# data-styled.g143[id="styled__FooterContainer-sc-1shly5-0"]{content:"fctWAl,"}/*!sc*/
# .dEkzvb{background-color:#FFFFFF;}/*!sc*/
# data-styled.g144[id="styled__FooterContainerLinks-sc-1shly5-1"]{content:"dEkzvb,"}/*!sc*/
# .kTUZAV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:auto;min-height:auto;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;text-align:left;}/*!sc*/
# .kTUZAV > img,.kTUZAV > i{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;}/*!sc*/
# .kTUZAV > p{margin-left:5px;}/*!sc*/
# .dsDGZP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;min-height:auto;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;text-align:right;}/*!sc*/
# .dsDGZP > img,.dsDGZP > i{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;}/*!sc*/
# .dsDGZP > p{margin-right:5px;}/*!sc*/
# .eIaTDi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;min-height:auto;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;text-align:left;}/*!sc*/
# .eIaTDi > img,.eIaTDi > i{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;}/*!sc*/
# .eIaTDi > p{margin-left:5px;}/*!sc*/
# data-styled.g145[id="styled__ShieldContainer-sc-1opls7r-0"]{content:"kTUZAV,dsDGZP,eIaTDi,"}/*!sc*/
# .hEJfTo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;height:48px;padding-left:0.5rem;padding-right:0.5rem;max-width:1800px;margin:0 auto;}/*!sc*/
# .hEJfTo > * + *{margin-left:0.5rem;}/*!sc*/
# @media (max-width:900px){.hEJfTo{display:none;}}/*!sc*/
# data-styled.g147[id="styled__ClubesHeaderContainer-sc-1azasvg-0"]{content:"hEJfTo,"}/*!sc*/
# .afUtv{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin:0px;}/*!sc*/
# .afUtv figure svg{height:auto;width:auto;}/*!sc*/
# data-styled.g148[id="styled__LogoContainer-sc-1us5g58-0"]{content:"afUtv,"}/*!sc*/
# ...
# .eFOfUB .text-live{position:absolute;width:100%;left:0px;top:100%;color:#E32D38;font-family:'LaLiga Text';font-size:9px;line-height:120%;margin-top:2px;}/*!sc*/
# data-styled.g544[id="styled__ResultStyled-sc-63ojsf-3"]{content:"eFOfUB,"}/*!sc*/
# .kUffLO{position:relative;width:100%;}/*!sc*/
# data-styled.g545[id="styled__ListStyled-sc-1nkmudg-0"]{content:"kUffLO,"}/*!sc*/
# .eGiIWJ{background-color:#47475b;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:8px;margin-bottom:16px;}/*!sc*/
# @media (max-width:767px){.eGiIWJ{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;gap:4px;}}/*!sc*/
# data-styled.g547[id="styled__Advice-sc-1nkmudg-2"]{content:"eGiIWJ,"}/*!sc*/
# .fGOPcJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .fGOPcJ i{margin-top:2px;}/*!sc*/
# data-styled.g548[id="styled__AdviceTextContainer-sc-1nkmudg-3"]{content:"fGOPcJ,"}/*!sc*/
# .dDBegs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g549[id="styled__AdviceLink-sc-1nkmudg-4"]{content:"dDBegs,"}/*!sc*/
# .hXhUHl{width:100%;min-height:40px;background-color:#EAEAEA;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:4px;}/*!sc*/
# @media (max-width:767px){.hXhUHl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# data-styled.g550[id="styled__TitleStyled-sc-1nkmudg-5"]{content:"hXhUHl,"}/*!sc*/
# .fsmigy{width:100%;max-width:1296px;margin:0 auto;position:relative;}/*!sc*/
# @media (max-width:1296px){.fsmigy{padding:15px;}}/*!sc*/
# @media (max-width:900px){.fsmigy{padding:10px;}}/*!sc*/
# data-styled.g961[id="styled__Container-sc-1engvts-0"]{content:"fsmigy,"}/*!sc*/
# .dGYSem{min-height:226px;background-color:#FF4B44;padding:15px 0;margin-bottom:5px;position:relative;background-repeat:no-repeat;background-image:url(https://assets.laliga.com/assets/public/backgrounds/pattern.svg);background-position:right top;}/*!sc*/
# @media (max-width:1389px){.dGYSem{background-size:55%;background-position:135% 0%;}}/*!sc*/
# data-styled.g962[id="styled__SubHeaderCalendarWrap-sc-1engvts-1"]{content:"dGYSem,"}/*!sc*/
# .erGMkY{margin:20px 0 50px;}/*!sc*/
# data-styled.g964[id="styled__HeaderGroup-sc-1engvts-3"]{content:"erGMkY,"}/*!sc*/
# .iIALXG{-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;z-index:100;position:relative;max-width:300px;}/*!sc*/
# .iIALXG:first-child{z-index:5;}/*!sc*/
# .iIALXG:nth-child(2){z-index:4;}/*!sc*/
# .iIALXG:last-child{z-index:3;}/*!sc*/
# .styled__DropdownContainer-sc-1engvts-6 + .styled__DropdownContainer-sc-1engvts-6{margin-top:1rem;}/*!sc*/
# @media (max-width:767px){.iIALXG{max-width:initial;}}/*!sc*/
# data-styled.g967[id="styled__DropdownContainer-sc-1engvts-6"]{content:"iIALXG,"}/*!sc*/
# .bCmtgF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .bCmtgF > .ad-banner-top{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;padding-left:1rem;}/*!sc*/
# @media (max-width:767px){.bCmtgF{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# data-styled.g969[id="styled__SubHeaderCalendarGrid-sc-1engvts-8"]{content:"bCmtgF,"}/*!sc*/
# .jQITpe{padding-bottom:4px;width:100%;max-width:100vw;overflow-x:hidden;}/*!sc*/
# @media (min-width:992px){.jQITpe{min-height:600px;}}/*!sc*/
# data-styled.g971[id="styled__SkyWrapper-sc-dy5xzq-0"]{content:"jQITpe,"}/*!sc*/
# .eCLtZD{position:absolute;top:0px;right:calc(100% + 4px);}/*!sc*/
# .jtPaGY{position:absolute;top:0px;left:calc(100% + 4px);}/*!sc*/
# data-styled.g972[id="styled__PostionSky-sc-dy5xzq-1"]{content:"eCLtZD,jtPaGY,"}/*!sc*/
# .uEUcr{padding:30px 0 0;}/*!sc*/
# @media (max-width:767px){.uEUcr{padding:15px 0 0;}}/*!sc*/
# data-styled.g1128[id="styled__PaddingDiv-sc-sq8587-1"]{content:"uEUcr,"}/*!sc*/
# .duzZkl > a{display:block;padding:0.5rem 0.25rem;}/*!sc*/
# data-styled.g1129[id="styled__StyledLink-sc-sq8587-2"]{content:"duzZkl,"}/*!sc*/
# @-webkit-keyframes dbbDGu{0%{height:0px;}100%{height:0px;}}/*!sc*/
# @keyframes dbbDGu{0%{height:0px;}100%{height:0px;}}/*!sc*/
# data-styled.g1132[id="sc-keyframes-dbbDGu"]{content:"dbbDGu,"}/*!sc*/
# </style></head><body date-timestamp="20250124195139"><div id="__next"><div class="styled__SpinnerContainer-sc-uwgd15-0 fpSspd hide"><div></div></div><div class="styled__ClubesHeaderContainer-sc-1azasvg-0 hEJfTo"><p class="styled__TextStyled-sc-1mby3k1-0 dXgpqT">Web Clubs</p><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.athletic-club.eus/en" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s athletic-club"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://en.atleticodemadrid.com" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s atletico-de-madrid"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.osasuna.es/" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s c-a-osasuna"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.cdleganes.com/en" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s cd-leganes"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.deportivoalaves.com/" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s d-alaves"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.fcbarcelona.com/en" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s fc-barcelona"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.getafecf.com/" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s getafe-cf"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.gironafc.cat/en" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s girona-fc"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="http://www.rayovallecano.es/" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s rayo-vallecano"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="http://www.rccelta.es/index.php/en" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s rc-celta"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.rcdespanyol.com/es/" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s rcd-espanyol"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="http://www.rcdmallorca.es/en" rel="nofollow" target="_blank"><div class="styled__ShieldContainer-sc-1opls7r-0 kTUZAV"><i class="shield-sprite s rcd-mallorca"></i></div></a><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://en.realbetisbalompie.es/" rel="nofollow" target="_blank"><div  ...
#   	.t3510b87f-5cd5-45cb-96c4-c428b65b246d {
# 	    color: #fff;
# 	    background: #222;
# 	    border: 1px solid transparent;
# 	    border-radius: undefinedpx;
# 	    padding: 8px 21px;
#   	}
#
#   	.t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-top {
#         margin-top: -10px;
#     }
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-top::before {
#         content: "";
#         background-color: inherit;
#         position: absolute;
#         z-index: 2;
#         width: 20px;
#         height: 12px;
#     }
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-top::after {
#         content: "";
#         position: absolute;
#         width: 10px;
#         height: 10px;
#         border-top-right-radius: undefinedpx;
#         border: 1px solid transparent;
#         background-color: #222;
#         z-index: -2;
#         bottom: -6px;
#         left: 50%;
#         margin-left: -6px;
#         transform: rotate(135deg);
#     }
#
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-bottom {
#         margin-top: 10px;
#     }
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-bottom::before {
#         content: "";
#         background-color: inherit;
#         position: absolute;
#         z-index: -1;
#         width: 18px;
#         height: 10px;
#     }
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-bottom::after {
#         content: "";
#         position: absolute;
#         width: 10px;
#         height: 10px;
#         border-top-right-radius: undefinedpx;
#         border: 1px solid transparent;
#         background-color: #222;
#         z-index: -2;
#         top: -6px;
#         left: 50%;
#         margin-left: -6px;
#         transform: rotate(45deg);
#     }
#
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-left {
#         margin-left: -10px;
#     }
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-left::before {
#         content: "";
#         background-color: inherit;
#         position: absolute;
#         z-index: -1;
#         width: 10px;
#         height: 18px;
#     }
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-left::after {
#         content: "";
#         position: absolute;
#         width: 10px;
#         height: 10px;
#         border-top-right-radius: undefinedpx;
#         border: 1px solid transparent;
#         background-color: #222;
#         z-index: -2;
#         right: -6px;
#         top: 50%;
#         margin-top: -6px;
#         transform: rotate(45deg);
#     }
#
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-right {
#         margin-left: 10px;
#     }
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-right::before {
#         content: "";
#         background-color: inherit;
#         position: absolute;
#         z-index: -1;
#         width: 10px;
#         height: 18px;
#     }
#     .t3510b87f-5cd5-45cb-96c4-c428b65b246d.place-right::after {
#         content: "";
#         position: absolute;
#         width: 10px;
#         height: 10px;
#         border-top-right-radius: undefinedpx;
#         border: 1px solid transparent;
#         background-color: #222;
#         z-index: -2;
#         left: -6px;
#         top: 50%;
#         margin-top: -6px;
#         transform: rotate(-135deg);
#     }
#   </style></div><table class="styled__TableStyled-sc-43wy8s-1 ffaSZZ"><thead><tr class="styled__HeadRow-sc-43wy8s-2 fpJKYk"><th class="styled__HeadCell-sc-43wy8s-3 cGLmRY"></th><th class="styled__HeadCell-sc-43wy8s-3 cGLmRY"><span class="label" style="font-family:LaLiga Text Bold;font-size:12px;line-height:120%">DATE</span></th><th class="styled__HeadCell-sc-43wy8s-3 cGLmRY"><span class="label" style="font-family:LaLiga Text Bold;font-size:12px;line-height:120%">DATETIME</span><i class="styled__IconRegularContainer-sc-1lapsw7-0 hwIFst font-laliga icon-icono-help undefined" data-tip="Local time according to your device's settings"></i></th><th class="styled__HeadCell-sc-43wy8s-3 cGLmRY"><span class="label" style="font-family:LaLiga Text Bold;font-size:12px;line-height:120%">BALL</span></th><th class="styled__HeadCell-sc-43wy8s-3 cGLmRY"><span class="label" style="font-family:LaLiga Text Bold;font-size:12px;line-height:120%">MATCH</span></th><th class="styled__HeadCell-sc-43wy8s-3 cGLmRY"><span class="label" style="font-family:LaLiga Text Bold;font-size:12px;line-height:120%">REFEREE</span></th><th class="styled__HeadCell-sc-43wy8s-3 cGLmRY"><span class="label" style="font-family:LaLiga Text Bold;font-size:12px;line-height:120%">BROADCASTER</span></th><th class="styled__HeadCell-sc-43wy8s-3 cGLmRY"></th></tr></thead><tbody><tr class="styled__TableRow-sc-43wy8s-4 cPHitQ"><td class="styled__TableCell-sc-43wy8s-5 styled__TableCellAccordion-sc-43wy8s-9 hhcbkq uSDbT" rowspan="2"><div class="styled__TableCellAccordionTextContainer-sc-43wy8s-10 hKOeGZ"><p class="styled__TextStyled-sc-1mby3k1-0 bNUkWr">Watch summary</p></div><div><div style="margin-top:-4px"><i class="styled__IconRegularContainer-sc-1lapsw7-0 eLDrjN font-laliga icon-triangle_down undefined"></i></div></div></td><td class="styled__TableCell-sc-43wy8s-5 styled__DateTimeStyled-sc-1coav22-0 eaagjK lgKdU" type="date"><p class="styled__TextStyled-sc-1mby3k1-0 budAXc">THU 15.08.2024</p></td><td class="styled__TableCell-sc-43wy8s-5 styled__DateTimeStyled-sc-1coav22-0 gpnugR cDwLXM" type="time"><p class="styled__TextStyled-sc-1mby3k1-0 budAXc">17:00</p></td><td class="styled__TableCell-sc-43wy8s-5 kZigDv"><div class="lazyload-wrapper"><div class="lazyload-placeholder"></div></div></td><td class="styled__TableCell-sc-43wy8s-5 styled__TableCellMatch-sc-63ojsf-0 dEZQbx jXbbyR"><div class="styled__MatchStyled-sc-63ojsf-1 ikynfs"><div class="styled__ShieldStyled-sc-63ojsf-2 kSAoIV"><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/clubs/athletic-club/results" target="_self"><div class="styled__ShieldContainer-sc-1opls7r-0 dsDGZP"><i class="shield-sprite xs athletic-club"></i><p class="styled__TextStyled-sc-1mby3k1-0 jTXYPl">Athletic Club</p></div></a></div><div class="styled__ResultStyled-sc-63ojsf-3 eFOfUB"><div class="live"><p class="styled__TextStyled-sc-1mby3k1-0 gqRVUt">1</p><p class="styled__TextStyled-sc-1mby3k1-0 gqRVUt vs"> - </p><p class="styled__TextStyled-sc-1mby3k1-0 gqRVUt">1</p></div></div><div class="styled__ShieldStyled-sc-63ojsf-2 kSAoIV"><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/clubs/getafe-cf/results" target="_self"><div class="styled__ShieldContainer-sc-1opls7r-0 eIaTDi"><i class="shield-sprite xs getafe-cf"></i><p class="styled__TextStyled-sc-1mby3k1-0 jTXYPl">Getafe CF</p></div></a></div></div></td><td class="styled__TableCell-sc-43wy8s-5 kZigDv"><p class="styled__TextStyled-sc-1mby3k1-0 cwoAiu">Alejandro Muñiz Ruiz</p></td><td class="styled__TableCell-sc-43wy8s-5 kZigDv"><p class="styled__TextStyled-sc-1mby3k1-0 cwoAiu">-</p></td><td class="styled__TableCell-sc-43wy8s-5 styled__TableCellLink-sc-43wy8s-8 hhcbkq fVeghq" rowspan="2"><a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/match/temporada-2024-2025-laliga-ea-spor ...

# %%
match_week_options = soup.select('ul.styled__ItemsList-sc-d9k1bl-2 a')
match_week_options
# Out:
# [<a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.laliga.com/es-GB/laliga-easports/resultados/2024-25/jornada-1" target="_self">Español</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-1" target="_self">English</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.laliga.com/es-GB/laliga-easports/resultados/2024-25/jornada-1" target="_self">Español</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-1" target="_self">English</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-1" target="_self">Matchday 1</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-2" target="_self">Matchday 2</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-3" target="_self">Matchday 3</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-4" target="_self">Matchday 4</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-5" target="_self">Matchday 5</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-6" target="_self">Matchday 6</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-7" target="_self">Matchday 7</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-8" target="_self">Matchday 8</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-9" target="_self">Matchday 9</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-10" target="_self">Matchday 10</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-11" target="_self">Matchday 11</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-12" target="_self">Matchday 12</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-13" target="_self">Matchday 13</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-14" target="_self">Matchday 14</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-15" target="_self">Matchday 15</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-16" target="_self">Matchday 16</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-17" target="_self">Matchday 17</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-18" target="_self">Matchday 18</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-19" target="_self">Matchday 19</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-20" target="_self">Matchday 20</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-21" target="_self">Matchday 21</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-22" target="_self">Matchday 22</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-23" target="_self">Matchday 23</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-24" target="_self">Matchday 24</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-25" target="_self">Matchday 25</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-26" target="_self">Matchday 26</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-27" target="_self">Matchday 27</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-28" target="_self">Matchday 28</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-29" target="_self">Matchday 29</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-30" target="_self">Matchday 30</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-31" target="_self">Matchday 31</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-32" target="_self">Matchday 32</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-33" target="_self">Matchday 33</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-34" target="_self">Matchday 34</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-35" target="_self">Matchday 35</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-36" target="_self">Matchday 36</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-37" target="_self">Matchday 37</a>,
#  <a class="link" datachangelang="[object Object]" globaldata="[object Object]" gptbase="/laliga-easports/resultados" href="/en-GB/laliga-easports/results/2024-25/gameweek-38" target="_self">Matchday 38</a>]

# %%
#links not formatted
for link in match_week_options[4:]:
    print(link.get('href'))
# Out:
# /en-GB/laliga-easports/results/2024-25/gameweek-1
# /en-GB/laliga-easports/results/2024-25/gameweek-2
# /en-GB/laliga-easports/results/2024-25/gameweek-3
# /en-GB/laliga-easports/results/2024-25/gameweek-4
# /en-GB/laliga-easports/results/2024-25/gameweek-5
# /en-GB/laliga-easports/results/2024-25/gameweek-6
# /en-GB/laliga-easports/results/2024-25/gameweek-7
# /en-GB/laliga-easports/results/2024-25/gameweek-8
# /en-GB/laliga-easports/results/2024-25/gameweek-9
# /en-GB/laliga-easports/results/2024-25/gameweek-10
# /en-GB/laliga-easports/results/2024-25/gameweek-11
# /en-GB/laliga-easports/results/2024-25/gameweek-12
# /en-GB/laliga-easports/results/2024-25/gameweek-13
# /en-GB/laliga-easports/results/2024-25/gameweek-14
# /en-GB/laliga-easports/results/2024-25/gameweek-15
# /en-GB/laliga-easports/results/2024-25/gameweek-16
# /en-GB/laliga-easports/results/2024-25/gameweek-17
# /en-GB/laliga-easports/results/2024-25/gameweek-18
# /en-GB/laliga-easports/results/2024-25/gameweek-19
# /en-GB/laliga-easports/results/2024-25/gameweek-20
# /en-GB/laliga-easports/results/2024-25/gameweek-21
# /en-GB/laliga-easports/results/2024-25/gameweek-22
# /en-GB/laliga-easports/results/2024-25/gameweek-23
# /en-GB/laliga-easports/results/2024-25/gameweek-24
# /en-GB/laliga-easports/results/2024-25/gameweek-25
# /en-GB/laliga-easports/results/2024-25/gameweek-26
# /en-GB/laliga-easports/results/2024-25/gameweek-27
# /en-GB/laliga-easports/results/2024-25/gameweek-28
# /en-GB/laliga-easports/results/2024-25/gameweek-29
# /en-GB/laliga-easports/results/2024-25/gameweek-30
# /en-GB/laliga-easports/results/2024-25/gameweek-31
# /en-GB/laliga-easports/results/2024-25/gameweek-32
# /en-GB/laliga-easports/results/2024-25/gameweek-33
# /en-GB/laliga-easports/results/2024-25/gameweek-34
# /en-GB/laliga-easports/results/2024-25/gameweek-35
# /en-GB/laliga-easports/results/2024-25/gameweek-36
# /en-GB/laliga-easports/results/2024-25/gameweek-37
# /en-GB/laliga-easports/results/2024-25/gameweek-38

# %%
#formatted properly
game_week_links = ['https://www.laliga.com' + link.get('href')  for link in match_week_options[4:]]
game_week_links
# Out:
# ['https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-1',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-2',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-3',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-4',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-5',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-6',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-7',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-8',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-9',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-10',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-11',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-12',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-13',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-14',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-15',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-16',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-17',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-18',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-19',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-20',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-21',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-22',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-23',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-24',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-25',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-26',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-27',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-28',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-29',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-30',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-31',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-32',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-33',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-34',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-35',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-36',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-37',
#  'https://www.laliga.com/en-GB/laliga-easports/results/2024-25/gameweek-38']

# %%
def get_raw_game_week_df(week_number):
    game_week = game_week_links[week_number - 1]
    #html from page
    data = requests.get(game_week).text   
    #get table and make df
    df = pd.read_html(data)[0]
    return df
get_raw_game_week_df(23)
# Out:
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
#        Unnamed: 0                           DATE  \
# 0   Watch summary                 VIE 07.02.2025
# 1   Watch summary                    Watch Match
# 2             NaN                            NaN
# 3   Watch summary                 SÁB 08.02.2025
# 4   Watch summary                    Watch Match
# 5             NaN                            NaN
# 6   Watch summary                 SÁB 08.02.2025
# 7   Watch summary                    Watch Match
# 8             NaN                            NaN
# 9   Watch summary                 SÁB 08.02.2025
# 10  Watch summary  Horario peninsularWatch Match
# 11            NaN                            NaN
# 12  Watch summary                 SÁB 08.02.2025
# 13  Watch summary                    Watch Match
# 14            NaN                            NaN
# 15  Watch summary                 DOM 09.02.2025
# 16  Watch summary                    Watch Match
# 17            NaN                            NaN
# 18  Watch summary                 DOM 09.02.2025
# 19  Watch summary                    Watch Match
# 20            NaN                            NaN
# 21  Watch summary                 DOM 09.02.2025
# 22  Watch summary                    Watch Match
# 23            NaN                            NaN
# 24  Watch summary                 DOM 09.02.2025
# 25  Watch summary                   *Watch Match
# 26            NaN                            NaN
# 27  Watch summary                 LUN 10.02.2025
# 28  Watch summary                    Watch Match
# 29            NaN                            NaN
#
#                          DATETIME                           BALL  \
# 0                           20:00                            NaN
# 1                     Watch Match                    Watch Match
# 2                             NaN                            NaN
# 3                           13:00                            NaN
# 4                     Watch Match                    Watch Match
# 5                             NaN                            NaN
# 6                           15:15                            NaN
# 7                     Watch Match                    Watch Match
# 8                             NaN                            NaN
# 9                           17:30                            NaN
# 10  Horario peninsularWatch Match  Horario peninsularWatch Match
# 11                            NaN                            NaN
# 12                          20:00                            NaN
# 13                    Watch Match                    Watch Match
# 14                            NaN                            NaN
# 15                          13:00                            NaN
# 16                    Watch Match                    Watch Match
# 17                            NaN                            NaN
# 18                          15:15                            NaN
# 19                    Watch Match                    Watch Match
# 20                            NaN                            NaN
# 21                          17:30                            NaN
# 22                    Watch Match                    Watch Match
# 23                            NaN                            NaN
# 24                          20:00                            NaN
# 25                   *Watch Match                   *Watch Match
# 26                            NaN                            NaN
# 27                          20:00                            NaN
# 28                    Watch Match                    Watch Match
# 29                            NaN                            NaN
#
#                                          MATCH                        REFEREE  \
# 0         Rayo Vallecano VS Real Valladolid CF                              -
# 1                                  Watch Match                    Watch Match
# 2                                          NaN                            NaN
# 3                       RC Celta VS Real Betis                              -
# 4                                  Watch Match                    Watch Match
# 5                                          NaN                            NaN
# 6                   Athletic Club VS Girona FC                              -
# 7                                  Watch Match                    Watch Match
# 8                                          NaN                            NaN
# 9               UD Las Palmas VS Villarreal CF                              -
# 10               Horario peninsularWatch Match  Horario peninsularWatch Match
# 11                                         NaN                            NaN
# 12           Real Madrid VS Atlético de Madrid                              -
# 13                                 Watch Match                    Watch Match
# 14                                         NaN                            NaN
# 15               Deportivo Alavés VS Getafe CF                              -
# 16                                 Watch Match                    Watch Match
# 17                                         NaN                            NaN
# 18                   Valencia CF VS CD Leganés                              -
# 19                                 Watch Match                    Watch Match
# 20                                         NaN                            NaN
# 21  Real Sociedad VS RCD Espanyol de Barcelona                              -
# 22                                 Watch Match                    Watch Match
# 23                                         NaN                            NaN
# 24                  Sevilla FC VS FC Barcelona                              -
# 25                                *Watch Match                   *Watch Match
# 26                                         NaN                            NaN
# 27                  RCD Mallorca VS CA Osasuna                              -
# 28                                 Watch Match                    Watch Match
# 29                                         NaN                            NaN
#
#                       BROADCASTER  Unnamed: 7
# 0                               -         NaN
# 1                     Watch Match         NaN
# 2                             NaN         NaN
# 3                               -         NaN
# 4                     Watch Match         NaN
# 5                             NaN         NaN
# 6                               -         NaN
# 7                     Watch Match         NaN
# 8                             NaN         NaN
# 9                               -         NaN
# 10  Horario peninsularWatch Match         NaN
# 11                            NaN         NaN
# 12                              -         NaN
# 13                    Watch Match         NaN
# 14                            NaN         NaN
# 15                              -         NaN
# 16                    Watch Match         NaN
# 17                            NaN         NaN
# 18                              -         NaN
# 19                    Watch Match         NaN
# 20                            NaN         NaN
# 21                              -         NaN
# 22                    Watch Match         NaN
# 23                            NaN         NaN
# 24                              -         NaN
# 25                   *Watch Match         NaN
# 26                            NaN         NaN
# 27                              -         NaN
# 28                    Watch Match         NaN
# 29                            NaN         NaN

# %%
def cleaned_df(week_number):
    raw_df = get_raw_game_week_df(week_number)
    df = raw_df.dropna(how='all').dropna(axis=1, how='all')
    columns_to_drop = [df.columns[0],df.columns[3],df.columns[6]]
    df = df.drop(columns_to_drop, axis=1)
    df = df.drop_duplicates(keep = False)
    # remove row if it contains: 'Horario peninsularWatch Match' 
    df = df.loc[~df['DATE'].str.contains("Horario peninsularWatch Match", na=False)].reset_index(drop=True)
    df = df.rename(columns = {'DATE': 'date', 'DATETIME': 'time', 'MATCH': 'match', 'REFEREE' : 'referee'})

    #error handling for matches that have not been played yet
    def parse_date(x):
        try:
            return datetime.strptime(x.split(' ', 1)[1], '%d.%m.%Y').strftime('%Y-%m-%d')
        except ValueError:
            return None
    df['date'] = df['date'].apply(parse_date)
    
    #if df does not contain '-' in the match column, None/nan will be inserted
    df['score']  = df['match'].apply(lambda x: f"{x.split('-')[0][-2]} - {x.split('-')[1][1]}" if '-' in x else None)
    df['match'] = df['match'].apply(lambda x: f"{x.split('-')[0][:-2:]} - {x.split('-')[1][2::]}" if '-' in x else None)
    df['home_goals'] = df['score'].apply(lambda x: f"{x.split('-')[0][0:1]}" if x else None)
    df['away_goals'] = df['score'].apply(lambda x: f"{x.split('-')[1][1:2]}" if x else None)
    df['home_team'] = df['match'].apply(lambda x: f"{x.split('-')[0][:-1]}" if x else None)
    df['away_team'] = df['match'].apply(lambda x: f"{x.split('-')[1][1:]}" if x else None)
    df['match_week'] = week_number
    df = df.dropna(axis=0)
    return df if df.empty != True else None
cleaned_df(21)
# Out:
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]

# %%
def get_current_dfs():
    individual_dfs = []
    
    for week,link in enumerate(game_week_links):
        week+=1
        df = cleaned_df(week)
        
        if df is not None:
            individual_dfs.append(df)
        else:
            break
            
    return individual_dfs
individual_dfs = get_current_dfs()
# Out:
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]
# /var/folders/d4/_r4v494n5x374v7382c56prc0000gn/T/ipykernel_29389/1036172830.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(data)[0]

# %%
main_df = pd.concat(individual_dfs, ignore_index=True)
# Out:
#            date   time                         match  \
# 0    2024-08-15  17:00     Athletic Club - Getafe CF
# 1    2024-08-15  19:30        Real Betis - Girona FC
# 2    2024-08-16  17:00   RC Celta - Deportivo Alavés
# 3    2024-08-16  19:30    UD Las Palmas - Sevilla FC
# 4    2024-08-17  17:00       CA Osasuna - CD Leganés
# ..          ...    ...                           ...
# 195  2025-01-19  13:00      RC Celta - Athletic Club
# 196  2025-01-19  15:15   Real Madrid - UD Las Palmas
# 197  2025-01-19  17:30   CA Osasuna - Rayo Vallecano
# 198  2025-01-19  20:00   Valencia CF - Real Sociedad
# 199  2025-01-20  20:00  Villarreal CF - RCD Mallorca
#
#                             referee  score home_goals away_goals  \
# 0              Alejandro Muñiz Ruiz  1 - 1          1          1
# 1          Miguel Ángel Ortiz Arias  1 - 1          1          1
# 2       Alejandro Quintero González  2 - 1          2          1
# 3    Francisco José Hernández Maeso  2 - 2          2          2
# 4          Juan Luis Pulido Santana  1 - 1          1          1
# ..                              ...    ...        ...        ...
# 195        Miguel Ángel Ortiz Arias  1 - 2          1          2
# 196     Alejandro Quintero González  4 - 1          4          1
# 197            Alejandro Muñiz Ruiz  1 - 1          1          1
# 198           Víctor García Verdura  1 - 0          1          0
# 199       José Luis Munuera Montero  4 - 0          4          0
#
#          home_team         away_team  match_week
# 0    Athletic Club         Getafe CF           1
# 1       Real Betis         Girona FC           1
# 2         RC Celta  Deportivo Alavés           1
# 3    UD Las Palmas        Sevilla FC           1
# 4       CA Osasuna        CD Leganés           1
# ..             ...               ...         ...
# 195       RC Celta     Athletic Club          20
# 196    Real Madrid     UD Las Palmas          20
# 197     CA Osasuna    Rayo Vallecano          20
# 198    Valencia CF     Real Sociedad          20
# 199  Villarreal CF      RCD Mallorca          20
#
# [200 rows x 10 columns]

# %%
main_df.to_csv('la_liga.csv')
